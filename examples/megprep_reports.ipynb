# %% [markdown]
# ## MEGPrep Reports
# **Note: The demo examples are presented in JupyterLab.**
# 1. You can run them with one click (⏩︎) or execute them step by step using the Play button (▶︎).
# 2. To save time, MEGPrep has already run successfully; we’ll open the report by running the command.

# %%
## COG dataset

# %%
# Launch the MEGPrep interactive report.
# !docker run --rm -it \
-p 8501:8501 \
-v "$(pwd)/cog_dataset/derivatives_demo":/output \
-v "$(pwd)/cog_dataset/smri":/smri \
cmrlab/megprep:0.0.3 -r
# Out:
# Executor:
# root
# Starting Streamlit to view the report...
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.17.0.2:8501
#   External URL: http://47.121.126.247:8501
#
# Using matplotlib as 2D backend.
# Opening raw data file /output/preprocessed/sub-01_task-aef_meg/sub-01_task-aef_meg_preproc-raw.fif...
#     Range : 1300 ... 19799 =     13.000 ...   197.990 secs
# Ready.
# Reading 0 ... 18499  =      0.000 ...   184.990 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# ...

# %%
## WAND dataset

# %%
# Launch the MEGPrep interactive report.
# !docker run --rm -it \
-p 8501:8501 \
-v "$(pwd)/wand_dataset/derivatives_demo":/output \
-v "$(pwd)/wand_dataset/smri":/smri \
cmrlab/megprep:0.0.3 -r
